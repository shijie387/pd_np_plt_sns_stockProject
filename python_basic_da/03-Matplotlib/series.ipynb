# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt

# %%
s1 = Series(np.random.randn(1000)).cumsum()
s2 = Series(np.random.randn(1000)).cumsum() #cumsum累加和

# %%
s1.plot(kind='line',grid=True,label='S1',title='This is Series')
s2.plot(label='S2')
# Out:
# <AxesSubplot:title={'center':'This is Series'}>

# %%
fig,ax=plt.subplots(2,1)
ax[0].plot(s1)
ax[1].plot(s2)

# %%
fig, ax = plt.subplots(2,1)

s1[0:10].plot(ax=ax[0], label='S1', kind='bar')
s2.plot(ax=ax[1], label='S2')
# Out:
# <AxesSubplot:>
